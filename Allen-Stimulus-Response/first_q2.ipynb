# %%
import pandas as pd

dat=pd.read_csv('first_q_test.csv')

# %%
clip_columns = dat.filter(regex='var_exp_clip_\d+')
dino_columns = dat.filter(regex='var_exp_dino_\d+')
print(clip_columns)
print(dino_columns)
# Out:
#      var_exp_clip_0  var_exp_clip_1  var_exp_clip_2  var_exp_clip_3  \
# 0          0.494567        0.037395       -0.171750       -0.230359
# 1         -0.155019       -0.393024       -0.266248       -0.244108
# 2         -0.213935       -0.209699        0.557439       -0.009851
# 3         -0.035831       -0.233728       -0.270546       -0.147979
# 4          0.647461       -0.041801       -0.166585        0.729041
# ..              ...             ...             ...             ...
# 207        0.539820       -0.221601       -0.228054        0.690843
# 208       -0.120002       -0.266433       -0.243409       -0.197020
# 209       -0.046240       -0.235682       -0.210315       -0.103985
# 210        0.761717       -0.115164       -0.221195       -0.050876
# 211        0.007484       -0.181140       -0.066902       -0.264702
#
#      var_exp_clip_4  var_exp_clip_5  var_exp_clip_6  var_exp_clip_7  \
# 0         -0.203329        0.511891        0.465673       -0.169883
# 1         -0.280720       -0.304755       -0.025550       -0.497277
# 2         -0.232130       -0.210173       -0.029795       -0.104038
# 3         -0.115399       -0.292119       -0.361227       -0.160190
# 4         -0.140166       -0.160031       -0.083237       -0.055201
# ..              ...             ...             ...             ...
# 207        0.262026        0.255220       -0.329482        0.221502
# 208       -0.181067       -0.267965       -0.211538       -0.294227
# 209       -0.265321        0.061181       -0.510685        0.096577
# 210       -0.229745       -0.256147       -0.391496       -0.253120
# 211       -0.032261       -0.336184       -0.093491       -0.009448
#
#      var_exp_clip_8  var_exp_clip_9
# 0          0.573198        0.148975
# 1         -0.200506       -0.262937
# 2          0.017853       -0.094214
# 3         -0.019664       -0.188942
# 4          0.314083       -0.156013
# ..              ...             ...
# 207        0.086165        0.124663
# 208       -0.099070       -0.187007
# 209        0.007315       -0.125376
# 210       -0.097518       -0.474451
# 211        0.677689       -0.321459
#
# [212 rows x 10 columns]
#      var_exp_dino_0  var_exp_dino_1  var_exp_dino_2  var_exp_dino_3  \
# 0          0.490074       -0.002500       -0.159188       -0.146903
# 1         -0.158749       -0.457406       -0.211686       -0.221855
# 2         -0.203110       -0.207027        0.659916        0.116489
# 3         -0.006775       -0.224008       -0.168443       -0.100471
# 4          0.712072        0.017136       -0.077163        0.719858
# ..              ...             ...             ...             ...
# 207        0.545287       -0.139265       -0.235725        0.706726
# 208       -0.150058       -0.326560       -0.158637       -0.176167
# 209       -0.076187       -0.322575       -0.244575       -0.081695
# 210        0.850452       -0.095164       -0.189976       -0.082109
# 211        0.031286       -0.200195       -0.068652       -0.240099
#
#      var_exp_dino_4  var_exp_dino_5  var_exp_dino_6  var_exp_dino_7  \
# 0         -0.170752        0.546074        0.414112       -0.223063
# 1         -0.264793       -0.323145       -0.016849       -0.444123
# 2         -0.256697       -0.213411        0.106469       -0.172645
# 3         -0.106919       -0.320356       -0.227485       -0.140442
# 4         -0.197228       -0.237077       -0.034502       -0.018445
# ..              ...             ...             ...             ...
# 207        0.346254        0.313811       -0.261533        0.210360
# 208       -0.230363       -0.331842       -0.157702       -0.309714
# 209       -0.263541       -0.051268       -0.549030        0.141778
# 210       -0.242898       -0.275742       -0.301553       -0.220808
# 211       -0.212015       -0.237068       -0.027313        0.021534
#
#      var_exp_dino_8  var_exp_dino_9
# 0          0.659114        0.124813
# 1         -0.172813       -0.272480
# 2         -0.015870       -0.166659
# 3         -0.011999       -0.144349
# 4          0.381211       -0.208370
# ..              ...             ...
# 207        0.150274        0.118596
# 208       -0.027080       -0.172318
# 209        0.019860       -0.197062
# 210       -0.130404       -0.356988
# 211        0.620877       -0.230405
#
# [212 rows x 10 columns]

# %%
import numpy as np
mean_clip=np.mean(clip_columns,axis=1)
mean_dino=np.mean(dino_columns,axis=1)
std_clip=np.std(clip_columns,axis=1)
std_dino=np.std(dino_columns,axis=1)

# %%
import matplotlib.pyplot as plt
plt.scatter(mean_clip, std_clip)

# %%
plt.scatter(mean_dino,std_dino)

# %%
plt.scatter(std_clip,std_dino)
